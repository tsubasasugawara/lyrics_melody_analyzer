# %%
from alm.lyrics import *
import pprint

# %%
import os
os.chdir("../")

# %%
file_path = "tests/files/unpopular/人_A2.xml"

# %%
parser = grammar_parser.GrammarParser("ja_ginza")

lyrics_notes_map = lyrics_extractor.extract_lyrics(file_path)
doc = parser.parse(lyrics_notes_map[lyrics_extractor.LYRICS_KEY])
lyrics_tree = parser.to_tree(doc)

pprint.pprint(lyrics_tree.to_dict())
# Out:
# {'children': [{'children': [{'children': [{'children': [{'children': [{'children': [],
#                                                                        'end': True,
#                                                                        'id': 14,
#                                                                        'word': 'は'}],
#                                                          'end': False,
#                                                          'id': 13,
#                                                          'word': '今'},
#                                                         {'children': [],
#                                                          'end': True,
#                                                          'id': 16,
#                                                          'word': 'て'}],
#                                            'end': False,
#                                            'id': 15,
#                                            'word': '辛く'},
#                                           {'children': [],
#                                            'end': True,
#                                            'id': 17,
#                                            'word': '二人'},
#                                           {'children': [{'children': [],
#                                                          'end': True,
#                                                          'id': 19,
#                                                          'word': 'は'}],
#                                            'end': False,
#                                            'id': 18,
#                                            'word': '今'},
#                                           {'children': [{'children': [{'children': [{'children': [],
#                                                                                      'end': True,
#                                                                                      'id': 20,
#                                                                                      'word': 'この'},
#                                                                                     {'children': [],
#                                                                                      'end': True,
#                                                                                      'id': 22,
#                                                                                      'word': 'に'},
#                                                                                     {'children': [],
#                                                                                      'end': True,
#                                                                                      'id': 23,
#                                                                                      'word': 'は'}],
#                                                                        'end': False,
#                                                                        'id': 21,
#                                                                        'word': '手'}],
#                                                          'end': False,
#                                                          'id': 24,
#                                                          'word': '握る'},
#                                                         {'children': [],
#                                                          'end': True,
#                                                          'id': 26,
#                                                          'word': 'も'}],
#                                            'end': False,
#                                            'id': 25,
#                                            'word': '手'},
#                                           {'children': [],
#                                            'end': True,
#                                            'id': 28,
#                                            'word': 'て'}],
#                              'end': False,
#                              'id': 27,
#                              'word': 'なく'},
#                             {'children': [{'children': [],
#                                            'end': True,
#                                            'id': 30,
#                                            'word': 'が'}],
#                              'end': False,
#                              'id': 29,
#                              'word': '日々'},
#                             {'children': [],
#                              'end': True,
#                              'id': 32,
#                              'word': 'て'}],
#                'end': False,
#                'id': 31,
#                'word': '過ぎ'},
#               {'children': [{'children': [{'children': [{'children': [{'children': [],
#                                                                        'end': True,
#                                                                        'id': 1,
#                                                                        'word': 'の'}],
#                                                          'end': False,
#                                                          'id': 0,
#                                                          'word': '机'},
#                                                         {'children': [],
#                                                          'end': True,
#                                                          'id': 3,
#                                                          'word': 'の'}],
#                                            'end': False,
#                                            'id': 2,
#                                            'word': '横'},
#                                           {'children': [],
#                                            'end': True,
#                                            'id': 5,
#                                            'word': 'は'}],
#                              'end': False,
#                              'id': 4,
#                              'word': '写真'},
#                             {'children': [{'children': [],
#                                            'end': True,
#                                            'id': 7,
#                                            'word': 'も'}],
#                              'end': False,
#                              'id': 6,
#                              'word': '今'},
#                             {'children': [{'children': [],
#                                            'end': True,
#                                            'id': 10,
#                                            'word': 'いる'}],
#                              'end': False,
#                              'id': 9,
#                              'word': 'て'},
#                             {'children': [],
#                              'end': True,
#                              'id': 11,
#                              'word': 'から'},
#                             {'children': [],
#                              'end': True,
#                              'id': 12,
#                              'word': 'さ'}],
#                'end': False,
#                'id': 8,
#                'word': '笑っ'}],
#  'end': False,
#  'id': 33,
#  'word': 'いく'}
