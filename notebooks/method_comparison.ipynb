# %%
import numpy as np
import pandas as pd
import japanize_matplotlib
import matplotlib.pyplot as plt
import os

# %matplotlib inline
os.chdir("../")

# %%
def calc_stddev(data: list):
    return np.std(data, ddof=1)

# %%
def histplot(data, title:str, xlabel:str):
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)

    ax.hist(data)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel("度数")

# %%
df1 = pd.read_csv("csv/GReeeeN_tree_similarity_by_subtree_count_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tree_similarity_by_subtree_count_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="部分木の個数計算による類似度の頻度分布（重みなし）", xlabel="類似度（階級）")
# Out:
# 0.03252211878302526

# %%
df1 = pd.read_csv("csv/GReeeeN_tree_similarity_by_parent_child_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tree_similarity_by_parent_child_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の頻度分布（重みなし）", xlabel="類似度（階級）")
# Out:
# 0.1061573839297996

# %%
df1 = pd.read_csv("csv/GReeeeN_word_matched_rate_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_word_matched_rate_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="単語の一致率の頻度分布（重みなし）", xlabel="類似度（階級）")
# Out:
# 0.09533669851446247
