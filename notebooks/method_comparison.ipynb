# %%
import numpy as np
import pandas as pd
import japanize_matplotlib
import matplotlib.pyplot as plt
import os

# %matplotlib inline
os.chdir("../")

# %%
def calc_stddev(data: list):
    return np.std(data, ddof=1)

# %%
def histplot(data, title:str, xlabel:str, bins:int=20):
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)

    ax.hist(data, bins=bins, range=(0, 1))
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel("度数")

# %%
df1 = pd.read_csv("csv/GReeeeN_wmr_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_wmr_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="単語の一致率の度数分布（重みなし）", xlabel="類似度（階級）")
# Out:
# 0.09533669851446247

# %%
df1 = pd.read_csv("csv/GReeeeN_ts_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_ts_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="部分木の個数計算による類似度の度数分布（重みなし）", xlabel="類似度（階級）")
# Out:
# 0.03162833755038608

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（重みなし）", xlabel="類似度（階級）")
# Out:
# 0.10473883611869095

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w1_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w1_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w1）", xlabel="類似度（階級）")
# Out:
# 0.13003102132771777

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w2_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w2_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w2）", xlabel="類似度（階級）")
# Out:
# 0.08275344154374957

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w3_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w3_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w3）", xlabel="類似度（階級）")
# Out:
# 0.06520971808365797

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w4_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w4_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w4）", xlabel="類似度（階級）")
# Out:
# 0.11619617551568055

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w5_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w5_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w5）", xlabel="類似度（階級）")
# Out:
# 0.13973538273787764

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w6_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w6_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w6）", xlabel="類似度（階級）")
# Out:
# 0.07274049903229504

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w7_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w7_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w7）", xlabel="類似度（階級）")
# Out:
# 0.08292954972326234

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w8_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w8_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w8）", xlabel="類似度（階級）")
# Out:
# 0.13302309054266434

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w9_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w9_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w9）", xlabel="類似度（階級）")
# Out:
# 0.11044212874758562

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w10_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w10_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w10）", xlabel="類似度（階級）")
# Out:
# 0.056351765778259094

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w11_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w11_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w11）", xlabel="類似度（階級）")
# Out:
# 0.10359422086423425

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w12_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w12_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w12）", xlabel="類似度（階級）")
# Out:
# 0.14149064161227326

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w13_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w13_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w13）", xlabel="類似度（階級）")
# Out:
# 0.0986633610691348

# %%
df1 = pd.read_csv("csv/GReeeeN_tspc_w14_20231119.csv")
df2 = pd.read_csv("csv/ヨルシカ_tspc_w14_20231119.csv")
data = pd.concat([df1, df2])
rates = pd.concat([data.numerator_A / data.denominator_A, data.numerator_S / data.denominator_S], axis=0)

print(calc_stddev(rates))
histplot(rates, title="親子関係による類似度の度数分布（w14）", xlabel="類似度（階級）")
# Out:
# 0.0986633610691348
